# %% [markdown]
# # African Institute for Mathematical Sciences – AIMS-SN

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # Birama SARR

# %% [markdown]
# # Init2Py-01 – Conditionals & For loops
#
#                   October 18, 2021

# %% [markdown]
# # 1 Summations and Products

# %% [markdown]
# 1. Compute the following expressions for a natural number n chosen by the user:

# %% [markdown]
# $$(i) \sum_{\substack{i=0\\i is odd}}^{n-1}(i+3)$$

# %% [markdown]
# $$(ii) \prod_{\substack{i=0\\i is even}}^{n-1}(i+3)$$

# %%
def odd():
    n = int(input("Donner un entier n :"))
    s = 0
    for i in range(n):
        if i%2 ==1:
            s += i +3
        else:
            s = s
    print(s)

# %%
odd()

# %%
def prod():
    m = int(input('Donner un nombre n:'))
    p,i = 1,1
    while i < m :
        if i%2==0:
            p *= i+3
        else : p = p
        i +=1
    print(p)

# %%
prod()

# %% [markdown]
# 2. Write a program that reads the number of the day of the week (from 0 to 6). If it is a
# working day, then the program will write the name of the corresponding day. Otherwise,
# it will write the word "Weekend".

# %%
def jour():
    j = int(input("Donner le numero du jour"))
    while j > 5:
        print("Donner le numero du jour")
        break
    l = ['Lundi','Mardi','Mercredi','Jeudi','Vendredi']
    i = 0
    if i in range(j):
        print('Le jour correspondant est:',l[j])
    else:
        print('"Weekend".')

# %%
jour()

# %% [markdown]
# 3. Make a program that, given a month number (from 0 to 11), indicates how many days it
# has (28, 30 or 31), ignoring the leap years.

# %%
def mois():
    i = int(input("give a month number"))
    M =['Janvier','Fevrier','Mars','Avril','Mai','Juin','Juillet','Aout','Septembre','Octobre','Novembre','Decembre']
    if i == 1:
        print('le mois correspondant est',M[1], 'il contient 28 jours.')
    elif i in [0,2,4,6,7,9,11]:
        print(' le mois correspondant est',M[i],'il contient 31 jours.')
    else:
        print('le mois correspondant est',M[i],'il contient 30 jours.')

# %%
mois()

# %% [markdown]
# 4. Write two versions of python code that displays your name 3 times. One version with a
# "for loop" and another version with a "while loop".

# %%
def name1():
    n = input('Donner votre nom :')
    for i in range(3):
        print(n)
def name2():
    n = input('Donner votre nom :')
    i = 0
    while i < 3:
        print(n)
        i =i+1

# %%
name1()

# %%
name2()

# %% [markdown]
# 5. Given two numbers $a_0$ and $a_1$, the Fibonacci sequence they generate is constructed from the recursion formula $a_{n+1} = a_n + a_{n-1}$. Calculate the first 15 terms of a Fibonacci sequence, asking the user the initial values.

# %%
def Fibonacci():
    a0 = int(input('Donner la valeur de a_0:'))
    a1 = int(input('Donner la valeur de a_1:'))
    s0 = (a0+a1)%2
    S = []
    for i in range(15):
        a0 = a1
        a1 = s0
        s0 = (a0 + a1)%2
        S.append(s0)
    print(S)

# %%
Fibonacci()

# %% [markdown]
# 6. Compute the first 30 terms of the sequence defined by $2x_{n+2} - x_{n+1} - 6x_n = 0$ sequence,
# given any two initial values $x_0$and $x_1$

# %%
def sequence():
    x0 = int(input('Donner la valeur de a_0:'))
    x1 = int(input('Donner la valeur de a_1:'))
    x = (6*x0+x1)//2
    X = []
    for i in range(30):
        x0 = x1
        x1 = x
        x = (6*x0 + x1)//2
        X.append(x)
    print(X)

# %%
sequence()

# %% [markdown]
# 7. a) Write python code to determine whether or not a year is a leap year. Be sure you
# know what a leap year is.

# %%
def annee():
    n = int(input("Donner l'annee"))
    if n%4 == 0:
        print("The year is a leap year")
    else:
        print("The year is'n a leap year")

# %%
annee()

# %% [markdown]
# b) Write the code using only logical operators, i.e. no conditional branching.

# %%
def b_annee():
    n = int(input("Donner l'annee"))
    m  = n%4
    return m == 0

# %%
b_annee()

# %% [markdown]
# 8. a) Write python code that computes the sum of the square of the first n natural numbers.
# One version with a "for loop" and another version with a "while loop".

# %%
def somcar1():
    N = int(input("Donner un nombre N :"))
    S = 0
    for i in range(N+1):
        S += i**2
    print(S)
    
def somcar2():
    N = int(input("Donner un nombre N :"))
    S,i = 0,0
    while i < N:
        S += i**2
        i+=1
    print(S)

# %%
somcar1()

# %% [markdown]
# b) Write python code that prints, for a natural number M, the smallest natural number
# n such that $1^2 + 2^2 + ... + n^2 \geq M$: One version with a "for loop" and another version
# with a "while loop".

# %%
def care1():
    N = int(input("Donner un nombre N :"))
    S,i = 0,1
    while i < N:
        S += i**2
        if S > N:
            break
        i+=1
    print(S)

def care2():
    N = int(input("Donner un nombre N :"))
    S,i = 0,1
    for i in range(N):
        S += i**2
        if S > N:
            break
        i+=1
    print(S)

# %%
care2()

# %% [markdown]
# 9. a) Write python code that prints all the divisors of a given natural number.

# %%
def div():
    n = int(input("Donner un entier n :"))
    d = []
    for j in range(1,n+1):
         if n%j == 0:
                d.append(j)
    return d

# %%
div()

# %% [markdown]
# b) Read an integer number input by the user and calculate its prime factors. This will
# just be some of its divisors.

# %%
def fact_prime():
    n = int(input("Donner un entier n:"))
    i = 2
    D = []
    while i * i <= n:
        if n % i:
            i += 1
        else:
            n //= i
            D.append(i)9
    if n > 1:
        D.append(n)
    return D

# %%
fact_prime()

# %% [markdown]
# 10. Read an integer number between n 0 and 9 and print its multiplication table up to N
# where N is another another natural number read by the program.

# %%
def table():
    f = int(input("Donner un nombre entre 0 et 9 :"))
    k = int(input("Donner le nombre de multiple :"))
    i = 0
    while i <= k:
        print(i, 'fois', f , '=', i*f)
        i+=1

# %%
table()

# %% [markdown]
# 11. Write a program that prints all the numbers between 0 and 40 that are multiples of 3, 7
# or 11.

# %%
def mul():
    for i in range(40):
        if i%3==0 or i%7 ==0 or i%11==0:
            print(i)

# %%
mul()

# %% [markdown]
# 12. Write python code that prints the floor of a float x. Recall that the floor of a float x is the
# largest integer value less than or equal to x, i.e. if $E[x]$ is the floor of $x$, then it satisfies,
# $E[x] = 1 + E[x - 1]$
# PS: On Friday, you will be asked to write a recursive version of the above program.

# %%
def part():
    r = float(input("donner un nombre réel :"))
    return (1+int(r-1))

# %%
part()

# %% [markdown]
# 13. Given a point in the plane by its Cartesian coordinates, determine in which quadrant it is
# $(1st, 2nd, 3rd, 4th)$, if it lies on an axis, or if it is the origin. Do this for several points in
# the same execution of the program until the user quits.

# %%
def cart():
    x = float(input("Donnee l'abscice du point :"))
    y = float(input("Donnee l'ordonnée du point :"))
    if x > 0 and y > 0:
        print(" le point de coordonnées","(",x,",",y,")","se situe dans le premier quadrant")
    elif x < 0 and y > 0:
        print("le point de coordonnées","(",x,",",y,")","se situe dans le deuxième quadrant")
    elif x < 0 and y < 0:
        print("le point de coordonnées","(",x,",",y,")","se situe dans le troisième quadrant")
    elif x > 0 and y < 0:
        print("le point de coordonnées","(",x,",",y,")","se situe dans le quatrième quadrant")
    else:
        print("le point se situe à l'origine du repère")

# %%
cart()

# %% [markdown]
# 14. Ask for an integer number between 0 and 9, denoted x. Once the user has entered a correct
# number (that is one in the range [0..10)) the program asks for a second integer number
# between 0 and 255, denoted max. The program continues asking for the number until it
# is correct (that it is in the range [0..256)). When this is done, show all multiples of x that
# are between 0 and max. Then, ask the user whether he/she wants to continue; if in the
# affirmative, ask for another couple of numbers, otherwise finish.

# %%
def mult_n():
        while 1: # 1 est toujours vrai -> boucle infinie
                lettre = input (" Si vous voulez quittrer, Tapez 'q' sinon tapper autre chose: ")
                if lettre == "q":
                    print ("Merci da bien vouloir quitter ")
                    break
                else:
                    x = int(input("Donner un entier compris entre 0 et 9 :"))
                    while  x <0 or x > 9:
                        x = int(input("Donner un entier compris entre 0 et 9 :"))
                    max = int(input("Donner un nombre comprie entre 0 et 255 :"))
                    while max < 0 or max > 255:
                        max = int(input("Donner un nombre comprie entre 0 et 255 :"))
                    S = []
                    for i in range(max) :
                        if i%x==0:
                            S.append(i)
                    print(S)

# %%
mult_n()
